# %% [markdown]
# Завдання 1

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("shopping_trends.csv")

# %%
df.shape
# Out:
# (3900, 19)

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# Customer ID                   int64
# Age                           int64
# Gender                       object
# Item Purchased               object
# Category                     object
# Purchase Amount (USD)         int64
# Location                     object
# Size                         object
# Color                        object
# Season                       object
# Review Rating               float64
# Subscription Status          object
# Payment Method               object
# Shipping Type                object
# Discount Applied             object
# Promo Code Used              object
# Previous Purchases            int64
# Preferred Payment Method     object
# Frequency of Purchases       object
# dtype: object

# %%
df.rename(columns=lambda x: x.lower().replace(' ', '_'), inplace=True)

# %% [markdown]
# 1. Гістограма віку (age):
# Побудуйте гістограму віку клієнтів, використовуючи Seaborn

# %%
plt.figure(figsize=(10, 8))
sns.histplot(data=df, x='age', bins=20, color='skyblue')
plt.title('Гістограма віку клієнтів')
plt.xlabel('Вік')
plt.ylabel('Частота')
# Out:
# Text(0, 0.5, 'Частота')

# %% [markdown]
# 2. Порівняння розподілу покупок за статтею (item_purchased):
# Створіть стовпчасту діаграму або графік розподілу, щоб порівняти, які
# товари покупають клієнти найчастіше.

# %%
plt.figure(figsize=(10, 8))
sns.countplot(data=df, y='item_purchased', palette='viridis', order=df['item_purchased'].value_counts().index)
plt.title('Розподіл покупок за статтею')
plt.xlabel('Частота')
plt.ylabel('Стаття покупки')
# Out:
# C:\Users\Stetsenko\AppData\Local\Temp\ipykernel_22876\2127595222.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, y='item_purchased', palette='viridis', order=df['item_purchased'].value_counts().index)
# Text(0, 0.5, 'Стаття покупки')

# %% [markdown]
# 3. Залежність між віком та сумою покупок (purchase_amount):
# Використовуйте scatter plot, щоб візуалізувати залежність між віком та
# сумою покупок

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(data=df, x='age', y='purchase_amount_(usd)', color='salmon')
plt.title('Залежність між віком та сумою покупок')
plt.xlabel('Вік')
plt.ylabel('Сума покупок')
# Out:
# Text(0, 0.5, 'Сума покупок')

# %% [markdown]
# 4. Графік розподілу оцінок товарів (review_rating):
# Побудуйте графік розподілу оцінок товарів для оцінки якості.

# %%
plt.figure(figsize=(10, 8))
sns.histplot(data=df, x='review_rating', bins=10, color='lightgreen')
plt.title('Графік розподілу оцінок товарів')
plt.xlabel('Оцінка товару')
# Out:
# Text(0.5, 0, 'Оцінка товару')

# %% [markdown]
# 5. Категоріальна діаграма для статі (gender):
# Створіть категоріальну діаграму, щоб відобразити розподіл покупок за
# статтею.

# %%
plt.figure(figsize=(10, 8))
sns.countplot(data=df, x='gender', palette='Set2')
plt.title('Розподіл покупок за статтею')
plt.xlabel('Стать')
# Out:
# C:\Users\Stetsenko\AppData\Local\Temp\ipykernel_22876\2876229478.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='gender', palette='Set2')
# Text(0.5, 0, 'Стать')

# %% [markdown]
# 6. Залежність між рейтингом і сумою покупок (review_rating і
# purchase_amount):
# Вивчіть, чи існує зв'язок між рейтингом товару і сумою покупок за
# допомогою scatter plot.

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(data=df, x='review_rating', y='purchase_amount_(usd)', color='orange')
plt.title('Залежність між рейтингом і сумою покупок')
plt.xlabel('Рейтинг')
plt.ylabel('Сума')
# Out:
# Text(0, 0.5, 'Сума')

# %% [markdown]
# 7. Сезонність покупок (season):
# Побудуйте стовпчату діаграму, яка відображає, в який сезон клієнти
# роблять найбільше покупок.

# %%
plt.figure(figsize=(10, 8))
sns.countplot(data=df, x='season', palette='husl')
plt.title('Сезонність покупок')
plt.xlabel('Сезон')
plt.ylabel('Частота покупок')
# Out:
# C:\Users\Stetsenko\AppData\Local\Temp\ipykernel_22876\2935949501.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='season', palette='husl')
# Text(0, 0.5, 'Частота покупок')

# %% [markdown]
# 8. Графік розподілу розмірів одягу (size):
# Створіть графік розподілу розмірів одягу, щоб визначити популярність
# різних розмірів.

# %%
plt.figure(figsize=(10, 8))
sns.countplot(data=df, x='size', palette='muted')
plt.title('Розподіл розмірів одягу')
plt.xlabel('Розмір одягу')
# Out:
# C:\Users\Stetsenko\AppData\Local\Temp\ipykernel_22876\1823636662.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='size', palette='muted')
# Text(0.5, 0, 'Розмір одягу')

# %% [markdown]
# 9. Кількість покупок відносно типу оплати (payment_method):
# Порівняйте, скільки покупок робиться за різними методами оплати за
# допомогою стовпчатої діаграми.

# %%
plt.figure(figsize=(10, 8))
sns.countplot(data=df, x='payment_method', palette='muted')
plt.title('Кількість покупок відносно типу оплати')
plt.xlabel('Метод')
plt.ylabel('Покупки')
# Out:
# C:\Users\Stetsenko\AppData\Local\Temp\ipykernel_22876\457042609.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='payment_method', palette='muted')
# Text(0, 0.5, 'Покупки')

# %% [markdown]
# 10.Залежність між кількістю попередніх покупок (previous_purchases) і
# сумою поточної покупки (purchase_amount):
# Створіть scatter plot для визначення, чи існує зв'язок між кількістю
# попередніх покупок та сумою поточної покупки.

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(data=df, x='previous_purchases', y='purchase_amount_(usd)', color='orange')
plt.title('Залежність між кількістю попередніх покупок та сумою поточної покупки')
plt.xlabel('Кількість')
plt.ylabel('Сума')
# Out:
# Text(0, 0.5, 'Сума')

# %% [markdown]
# Завдання
# Побудуйте графік теплової поверхні для візуалізації залежності між
# двома або більше числовими змінними на основі матриці даних,
# використовуючи бібліотеку Seaborn.

# %%
import numpy as np

data_matrix = np.random.rand(5, 5)

plt.figure(figsize=(10, 8))
sns.heatmap(data_matrix, cmap='coolwarm', annot=True, fmt=".2f")
plt.title('Графік теплової поверхні')
plt.xlabel('Ось X')
plt.ylabel('Ось Y')
# Out:
# Text(95.72222222222221, 0.5, 'Ось Y')
